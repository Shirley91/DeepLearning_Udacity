# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.749458
# Nearest to which: vdash, sena, fr, valentin, cartel, seaplane, hale, scot,
# Nearest to more: bayou, holbein, vernal, gettier, wilhelm, shusui, macabre, weinberger,
# Nearest to known: visigoths, yo, strasberg, employees, raaf, idriss, comparisons, maggiore,
# Nearest to zero: occitan, muni, maharal, tampering, hermas, handguard, jinnah, trier,
# Nearest to its: curled, geometries, antiprotons, disintegration, bryant, threw, dewar, juneau,
# Nearest to the: tuned, finishes, isabelle, sell, expos, tines, thessalonica, zine,
# Nearest to than: compactly, gonzales, ch, recover, matching, eu, molar, witte,
# Nearest to can: att, wordsworth, galatea, kaye, roman, rosenbaum, directorate, sighted,
# Nearest to were: locus, entirely, invitational, mateo, leisurely, limiting, escoffier, sphinx,
# Nearest to is: sophist, revolver, geosynchronous, gifford, colours, adret, headway, cassettes,
# Nearest to use: liv, repression, male, slaughtered, cadillac, ministers, folklorist, anastasius,
# Nearest to up: rko, quoting, wily, pim, hyperinsulinism, librivox, colonial, guthrie,
# Nearest to and: helpers, cellulose, hustler, coma, stephenson, comprehension, lfheim, breeders,
# Nearest to in: pro, unconscious, dniester, renovations, isbn, chao, colonel, transshipment,
# Nearest to as: rural, lithographs, province, durant, dyess, byng, distributed, looksmart,
# Nearest to th: vc, avtovaz, pontiff, starving, speeches, synodic, unwieldy, tradition,
# Average loss at step 2000: 4.367227
# Average loss at step 4000: 3.866136
# Average loss at step 6000: 3.792635
# Average loss at step 8000: 3.689088
# Average loss at step 10000: 3.612080
# Nearest to which: this, that, it, who, also, died, seaplane, already,
# Nearest to more: bayou, vernal, very, less, taxon, statute, grotesque, larger,
# Nearest to known: idriss, octavius, doris, visigoths, tyson, climax, employees, shanks,
# Nearest to zero: seven, eight, five, six, three, nine, four, two,
# Nearest to its: the, his, allahabad, lycopene, their, skaro, sans, expos,
# Nearest to the: this, its, a, his, an, primate, their, administer,
# Nearest to than: mensch, gonzales, focuses, endosymbiont, hasten, geophysical, proconsul, or,
# Nearest to can: may, would, could, zacharias, will, camus, kaunda, verbally,
# Nearest to were: are, was, have, undecidability, had, rooftops, business, shortcomings,
# Nearest to is: was, are, has, asylum, became, universally, sack, be,
# Nearest to use: anastasius, ministers, jehoram, tsh, liv, cubical, repression, same,
# Nearest to up: wily, librivox, rko, quoting, hyperinsulinism, hypoxic, sidespin, z,
# Nearest to and: or, but, of, melos, who, dc, valentinus, determine,
# Nearest to in: of, at, on, with, from, after, magazine, for,
# Nearest to as: memex, petals, comers, good, morley, constituci, flavored, batting,
# Nearest to th: four, eight, three, starving, aladdin, avtovaz, synodic, nine,
# Average loss at step 12000: 3.606953
# Average loss at step 14000: 3.574611
# Average loss at step 16000: 3.404081
# Average loss at step 18000: 3.459703
# Average loss at step 20000: 3.536450
# Nearest to which: this, that, who, it, there, actually, also, he,
# Nearest to more: less, very, prepaid, most, bayou, larger, vernal, rather,
# Nearest to known: idriss, such, wider, used, tyson, octavius, bower, doris,
# Nearest to zero: five, six, four, seven, three, nine, eight, two,
# Nearest to its: their, the, his, kanpur, her, allahabad, lycopene, yak,
# Nearest to the: its, their, his, this, an, iona, any, a,
# Nearest to than: or, mensch, endosymbiont, marriageable, transitions, focuses, gonzales, siding,
# Nearest to can: could, may, would, will, should, zacharias, must, cannot,
# Nearest to were: are, was, had, have, reina, be, by, is,
# Nearest to is: was, are, has, became, were, but, ryan, sack,
# Nearest to use: jehoram, ministers, tsh, cubical, increasing, blades, number, anastasius,
# Nearest to up: saffron, gneiss, hyperinsulinism, spandau, hypoxic, piet, librivox, quoting,
# Nearest to and: or, but, from, in, choral, which, with, for,
# Nearest to in: at, from, on, with, under, purana, and, during,
# Nearest to as: by, microtubule, comers, was, duet, slips, breaking, paran,
# Nearest to th: three, aladdin, starving, journalist, avtovaz, cornelis, one, seven,
# Average loss at step 22000: 3.508295
# Average loss at step 24000: 3.487597
# Average loss at step 26000: 3.486941
# Average loss at step 28000: 3.478943
# Average loss at step 30000: 3.502719
# Nearest to which: this, that, who, also, it, lute, but, bootstrap,
# Nearest to more: less, very, larger, most, highly, quite, prepaid, rather,
# Nearest to known: used, regarded, well, such, idriss, described, served, wider,
# Nearest to zero: five, eight, seven, four, nine, six, three, two,
# Nearest to its: their, the, his, allahabad, kanpur, her, programmatic, vab,
# Nearest to the: its, their, his, a, some, lycopene, corners, any,
# Nearest to than: or, endosymbiont, mensch, marriageable, transitions, much, build, uniqueness,
# Nearest to can: could, may, would, will, should, must, cannot, might,
# Nearest to were: are, have, was, had, reina, by, is, socratic,
# Nearest to is: was, has, are, sack, although, became, does, mintz,
# Nearest to use: jehoram, ministers, tsh, repression, flavours, anticipating, increasing, accent,
# Nearest to up: him, them, gneiss, saffron, off, out, hypoxic, hyperinsulinism,
# Nearest to and: or, but, in, of, lds, choral, imams, lost,
# Nearest to in: on, of, at, during, from, between, and, within,
# Nearest to as: or, winslow, enumeration, vite, recognisable, by, became, with,
# Nearest to th: six, seven, four, eight, zero, journalist, aladdin, cornelis,
# Average loss at step 32000: 3.505461
# Average loss at step 34000: 3.483879
# Average loss at step 36000: 3.458290
# Average loss at step 38000: 3.300800
# Average loss at step 40000: 3.425840
# Nearest to which: that, this, who, also, it, but, often, actually,
# Nearest to more: less, very, most, larger, highly, quite, greater, electroweak,
# Nearest to known: used, such, idriss, wider, regarded, described, possible, served,
# Nearest to zero: seven, five, nine, eight, six, four, three, metres,
# Nearest to its: their, his, the, her, some, mpla, kanpur, allahabad,
# Nearest to the: this, a, their, his, its, any, each, another,
# Nearest to than: or, endosymbiont, much, mensch, marriageable, transitions, build, denounces,
# Nearest to can: could, may, will, would, should, must, might, cannot,
# Nearest to were: are, have, was, had, be, bayer, being, although,
# Nearest to is: was, has, be, are, if, neoclassicism, remo, when,
# Nearest to use: jehoram, ministers, sadness, most, tsh, organisation, accent, abstract,
# Nearest to up: out, him, them, gneiss, off, saffron, hypoxic, compuserve,
# Nearest to and: or, but, in, radically, like, e, while, fullerton,
# Nearest to in: during, at, for, of, and, linnaeus, sinn, from,
# Nearest to as: delocalized, republika, traversal, numeric, palomino, duet, pseudopods, memex,
# Nearest to th: seven, cornelis, avtovaz, rd, watkins, starving, journalist, hideous,
# Average loss at step 42000: 3.434550
# Average loss at step 44000: 3.452916
# Average loss at step 46000: 3.446956
# Average loss at step 48000: 3.359130
# Average loss at step 50000: 3.388986
# Nearest to which: that, this, who, often, what, also, disadvantaged, these,
# Nearest to more: less, most, very, highly, quite, larger, greater, rather,
# Nearest to known: used, such, regarded, served, described, possible, idriss, well,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to its: their, his, the, her, mpla, allahabad, bleed, equilateral,
# Nearest to the: its, their, this, his, a, any, our, some,
# Nearest to than: or, much, but, endosymbiont, refrigerated, while, mensch, slightly,
# Nearest to can: could, may, would, will, should, must, cannot, might,
# Nearest to were: are, have, was, be, had, reina, been, being,
# Nearest to is: was, has, are, became, daw, be, patinkin, becomes,
# Nearest to use: ministers, most, list, rigs, origins, sadness, concern, jehoram,
# Nearest to up: off, them, out, him, gneiss, down, compuserve, saffron,
# Nearest to and: or, but, including, while, rowspan, satanic, however, hind,
# Nearest to in: within, during, on, jasper, since, between, throughout, including,
# Nearest to as: clarinets, watery, duet, regulates, eduskunta, traversal, became, deputy,
# Nearest to th: cornelis, rd, starving, three, st, six, watkins, gematria,
# Average loss at step 52000: 3.434148
# Average loss at step 54000: 3.424940
# Average loss at step 56000: 3.437953
# Average loss at step 58000: 3.397363
# Average loss at step 60000: 3.392150
# Nearest to which: that, this, what, it, these, who, but, however,
# Nearest to more: less, very, most, larger, highly, quite, rather, extremely,
# Nearest to known: used, such, regarded, described, possible, served, shamanic, called,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to its: their, his, the, her, kanpur, bleed, whose, mpla,
# Nearest to the: their, its, a, this, any, each, his, some,
# Nearest to than: or, much, endosymbiont, but, build, stimulating, far, transitions,
# Nearest to can: could, may, would, will, must, should, cannot, might,
# Nearest to were: are, have, was, reina, had, including, be, been,
# Nearest to is: was, are, has, be, although, when, but, remo,
# Nearest to use: jehoram, most, ministers, practice, concern, origins, popularity, fourth,
# Nearest to up: off, out, him, them, down, gneiss, saffron, together,
# Nearest to and: or, but, including, although, radically, imams, however, hind,
# Nearest to in: within, of, during, including, between, at, since, among,
# Nearest to as: duet, traversal, find, panspermia, nevertheless, enumeration, ral, truffaut,
# Nearest to th: five, six, four, eight, seven, starving, ce, rd,
# Average loss at step 62000: 3.238766
# Average loss at step 64000: 3.260956
# Average loss at step 66000: 3.403877
# Average loss at step 68000: 3.394017
# Average loss at step 70000: 3.359205
# Nearest to which: that, this, also, but, these, what, often, usually,
# Nearest to more: less, most, very, quite, highly, extremely, rather, larger,
# Nearest to known: used, regarded, described, served, such, called, possible, referred,
# Nearest to zero: five, four, six, eight, nine, seven, three, two,
# Nearest to its: their, his, the, her, unicameral, kanpur, whose, inductively,
# Nearest to the: its, this, a, their, any, each, these, bestseller,
# Nearest to than: or, but, while, much, far, endosymbiont, geophysical, slightly,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to were: are, was, have, had, reina, be, been, these,
# Nearest to is: was, has, are, be, sack, becomes, became, laetrile,
# Nearest to use: most, call, practice, comparing, form, fourth, concern, origins,
# Nearest to up: off, them, out, him, down, saffron, gneiss, together,
# Nearest to and: or, but, which, while, radically, wootz, remarriage, fullerton,
# Nearest to in: within, on, during, until, for, including, at, rel,
# Nearest to as: becomes, traversal, like, sae, charcot, alfredo, upsets, peculiarities,
# Nearest to th: bc, ce, four, seven, st, starving, rd, perigee,
# Average loss at step 72000: 3.374922
# Average loss at step 74000: 3.345740
# Average loss at step 76000: 3.314795
# Average loss at step 78000: 3.351054
# Average loss at step 80000: 3.380767
# Nearest to which: that, this, usually, both, also, counteract, often, what,
# Nearest to more: less, very, quite, most, highly, larger, rather, greater,
# Nearest to known: used, regarded, described, such, called, served, referred, possible,
# Nearest to zero: seven, five, six, eight, four, nine, three, metres,
# Nearest to its: their, his, her, the, whose, unicameral, our, alberti,
# Nearest to the: its, their, this, his, a, lotta, mboxx, beaux,
# Nearest to than: while, much, far, or, but, mensch, geophysical, hand,
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to were: are, was, have, had, been, be, being, became,
# Nearest to is: was, has, are, although, becomes, be, laetrile, contains,
# Nearest to use: call, jehoram, because, concern, form, allocation, list, comparing,
# Nearest to up: off, out, them, him, down, together, compuserve, saffron,
# Nearest to and: or, but, radically, ansi, while, including, scholastics, choral,
# Nearest to in: within, during, until, on, at, since, annunzio, of,
# Nearest to as: sclc, anaximenes, alfredo, panspermia, moshiach, lob, before, traversal,
# Nearest to th: bc, ce, rd, five, starving, boac, capablanca, fifth,
# Average loss at step 82000: 3.408072
# Average loss at step 84000: 3.410420
# Average loss at step 86000: 3.388046
# Average loss at step 88000: 3.354693
# Average loss at step 90000: 3.362883
# Nearest to which: that, this, also, usually, actually, these, what, but,
# Nearest to more: less, very, quite, most, highly, rather, extremely, anyway,
# Nearest to known: used, described, such, regarded, possible, referred, called, served,
# Nearest to zero: five, seven, six, eight, nine, four, three, u,
# Nearest to its: their, his, the, her, your, our, malraux, paddle,
# Nearest to the: its, his, their, this, mboxx, moivre, any, our,
# Nearest to than: much, or, peach, far, slightly, transitions, refrigerated, geophysical,
# Nearest to can: could, may, must, will, would, cannot, should, might,
# Nearest to were: are, had, was, have, although, maintains, while, bounces,
# Nearest to is: was, are, has, although, becomes, be, makes, requires,
# Nearest to use: need, concern, most, because, usage, call, treatment, jehoram,
# Nearest to up: off, out, them, him, down, together, away, back,
# Nearest to and: or, but, while, including, filmfour, adas, in, lems,
# Nearest to in: within, during, of, throughout, with, around, under, at,
# Nearest to as: panspermia, traversal, faulkner, bud, alfredo, palomino, xj, bee,
# Nearest to th: bc, seven, one, rd, ce, six, five, bce,
# Average loss at step 92000: 3.398730
# Average loss at step 94000: 3.252963
# Average loss at step 96000: 3.354205
# Average loss at step 98000: 3.246825
# Average loss at step 100000: 3.357859
# Nearest to which: that, this, usually, these, what, actually, also, often,
# Nearest to more: less, most, very, quite, highly, rather, larger, prepaid,
# Nearest to known: used, described, such, possible, regarded, available, referred, served,
# Nearest to zero: five, four, seven, eight, six, nine, three, two,
# Nearest to its: their, his, the, her, paddle, kanpur, unicameral, whose,
# Nearest to the: their, its, his, your, a, yukio, some, our,
# Nearest to than: or, much, peach, far, kludge, slightly, denounces, endosymbiont,
# Nearest to can: could, may, will, must, would, cannot, should, might,
# Nearest to were: are, was, had, these, have, those, being, been,
# Nearest to is: was, has, became, be, are, becomes, makes, although,
# Nearest to use: sense, usage, concern, practice, cause, treatment, most, jehoram,
# Nearest to up: off, out, them, him, together, down, away, compuserve,
# Nearest to and: but, or, including, although, like, while, however, radically,
# Nearest to in: within, during, throughout, on, until, at, from, drabble,
# Nearest to as: traversal, like, selectively, ionian, eretz, alfredo, alif, bud,
# Nearest to th: rd, ce, bc, fifth, starving, st, second, boac,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # how many words to consider left and right.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed,1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.092028
# Nearest to th: chopped, fait, macrophages, hatches, mishnah, gossip, ridiculous, structural,
# Nearest to by: counterpoint, westermann, kongsberg, eubacteria, legs, alexanderplatz, utero, ssl,
# Nearest to seven: settlement, ramadan, vrije, playback, sylvester, gatehouse, chaim, full,
# Nearest to the: zu, flavor, keenan, assassin, kinsman, diamagnetic, billions, strewn,
# Nearest to also: ctesiphon, governmental, rebuilt, remote, bellarmine, covering, ellsworth, excluded,
# Nearest to between: sportsman, advises, congestive, celebrity, aed, hitters, kut, dunst,
# Nearest to only: eigenvalue, stadiums, solstices, oats, rh, buckley, theorizes, heist,
# Nearest to time: computed, moisture, approximation, deals, skillfully, conference, phallic, mithraism,
# Nearest to may: pervading, retailer, reincorporated, ftl, innovated, sprinter, community, keitel,
# Nearest to have: resentment, goran, fonda, debacle, pascal, belshazzar, aleuts, wetland,
# Nearest to two: degrade, underworld, vespers, tiananmen, jamahiriya, linking, uranium, sciences,
# Nearest to with: freezing, impatience, prolific, being, merchandising, blanc, rhythmic, talkie,
# Nearest to to: kuiper, defending, exam, dagbladet, disloyalty, alleviated, ravi, misnomer,
# Nearest to be: thrives, announcers, castel, mk, hoping, bil, sussex, commencing,
# Nearest to about: tailor, remixes, manhood, zoltan, apis, surplus, creighton, things,
# Nearest to than: flipper, colonized, brasses, morrow, dix, buick, turner, cavelier,
# Average loss at step 2000: 4.577473
# Average loss at step 4000: 3.921447
# Average loss at step 6000: 3.714861
# Average loss at step 8000: 3.514299
# Average loss at step 10000: 3.472368
# Nearest to th: chopped, nine, mishnah, umberto, zero, polyurethane, panama, eusebio,
# Nearest to by: coining, miscellany, kirsten, straddling, having, wap, battlefields, thrace,
# Nearest to seven: eight, nine, six, five, four, three, zero, one,
# Nearest to the: a, any, its, his, parchment, this, an, tournaments,
# Nearest to also: ellefson, spans, often, insecure, schott, bedouin, herd, now,
# Nearest to between: dunst, setbacks, entomologist, himmler, nova, deposited, permutations, sportsman,
# Nearest to only: technique, coogan, it, rhetorician, eigenvalue, dispensed, retainers, lambar,
# Nearest to time: least, year, groove, phallic, wyatt, rinsing, thaler, riggs,
# Nearest to may: can, would, must, should, could, will, to, might,
# Nearest to have: has, had, be, countermeasures, revolts, harding, having, sixty,
# Nearest to two: five, zero, three, prosecutors, one, eight, four, dwarfed,
# Nearest to with: wallis, and, fun, midshipman, reached, during, bnf, ratifies,
# Nearest to to: will, would, may, could, can, should, must, dagbladet,
# Nearest to be: refer, have, become, castel, freely, being, ztt, preferentially,
# Nearest to about: substandard, radiant, apis, fasts, sy, ainsworth, frication, macarthur,
# Nearest to than: brasses, or, diem, energetic, imbalance, essayists, abdominal, incarnate,
# Average loss at step 12000: 3.483479
# Average loss at step 14000: 3.428559
# Average loss at step 16000: 3.430087
# Average loss at step 18000: 3.404571
# Average loss at step 20000: 3.209965
# Nearest to th: st, chopped, eight, nd, umberto, nine, veneration, mishnah,
# Nearest to by: vernon, when, stifle, dalits, encarta, into, with, boleslav,
# Nearest to seven: five, six, eight, zero, nine, four, three, two,
# Nearest to the: a, their, his, its, any, each, this, an,
# Nearest to also: still, often, which, where, now, that, never, questioner,
# Nearest to between: entomologist, sportsman, narcotics, spike, with, sumerians, through, against,
# Nearest to only: first, communicative, still, collect, implants, plotted, it, pleiades,
# Nearest to time: period, end, point, year, groove, meshech, suck, celeste,
# Nearest to may: can, would, must, could, will, should, might, cannot,
# Nearest to have: has, had, having, include, be, are, peel, produce,
# Nearest to two: four, three, five, zero, nine, six, tabloids, seven,
# Nearest to with: while, provides, atreides, like, between, tala, including, swims,
# Nearest to to: will, may, could, must, can, would, sola, dagbladet,
# Nearest to be: being, refer, have, ztt, respond, were, mulligan, is,
# Nearest to about: tumble, paine, mastiff, irritable, among, semite, elision, airforce,
# Nearest to than: or, brasses, diem, energetic, incarnate, konqueror, buying, but,
# Average loss at step 22000: 3.363221
# Average loss at step 24000: 3.292028
# Average loss at step 26000: 3.253298
# Average loss at step 28000: 3.282240
# Average loss at step 30000: 3.232948
# Nearest to th: nd, nine, chopped, st, rd, nineteenth, carp, serpents,
# Nearest to by: through, when, massed, timbers, straddling, kirsten, who, from,
# Nearest to seven: nine, eight, five, six, four, three, zero, highlanders,
# Nearest to the: their, a, its, this, our, his, an, banzer,
# Nearest to also: now, never, below, often, still, lleyton, monarchies, where,
# Nearest to between: with, entomologist, hsv, encountering, spike, across, sportsman, in,
# Nearest to only: always, first, launches, yet, evasive, spiritually, underestimate, preserves,
# Nearest to time: end, least, period, point, movimiento, groove, celeste, dug,
# Nearest to may: would, can, could, will, must, should, might, does,
# Nearest to have: has, had, having, include, produce, require, are, contain,
# Nearest to two: three, four, one, six, five, eight, ry, fife,
# Nearest to with: between, while, ninlil, among, including, checker, and, toward,
# Nearest to to: will, would, could, must, can, dagbladet, should, cannot,
# Nearest to be: being, refer, respond, become, ztt, been, produce, neuromancer,
# Nearest to about: on, over, patois, mame, cyclopedia, ctbt, realists, voiceover,
# Nearest to than: diem, or, but, unsubstantiated, emphasized, much, adapting, santos,
# Average loss at step 32000: 3.008755
# Average loss at step 34000: 3.208552
# Average loss at step 36000: 3.200838
# Average loss at step 38000: 3.151360
# Average loss at step 40000: 3.167299
# Nearest to th: nine, nd, nineteenth, rd, chopped, st, twentieth, seventeenth,
# Nearest to by: when, through, using, timbers, fooled, straddling, kirsten, abdur,
# Nearest to seven: six, eight, five, four, zero, three, nine, volume,
# Nearest to the: its, a, their, any, his, this, another, an,
# Nearest to also: below, still, never, now, ellefson, often, usually, tunis,
# Nearest to between: with, within, across, entomologist, narcotics, among, flavoured, scorned,
# Nearest to only: always, collect, receiving, usually, verbal, unwitting, still, karpov,
# Nearest to time: end, point, beginning, groove, leahy, least, period, year,
# Nearest to may: can, must, could, would, will, should, might, cannot,
# Nearest to have: had, has, having, contain, provide, be, were, huey,
# Nearest to two: three, five, four, six, nine, zero, several, akiva,
# Nearest to with: between, while, bnf, granitic, when, rupture, mammalian, ornithology,
# Nearest to to: would, must, may, will, should, might, could, can,
# Nearest to be: being, respond, refer, exist, is, been, go, produce,
# Nearest to about: on, over, racist, why, tumble, elision, tribute, realists,
# Nearest to than: but, or, diem, while, brasses, dk, much, rastafari,
# Average loss at step 42000: 3.212970
# Average loss at step 44000: 3.146707
# Average loss at step 46000: 3.136533
# Average loss at step 48000: 3.058023
# Average loss at step 50000: 3.051557
# Nearest to th: nineteenth, twentieth, nine, st, rd, nd, chopped, recombinant,
# Nearest to by: without, through, when, timbers, flintlock, straddling, simplifies, since,
# Nearest to seven: eight, nine, six, five, four, three, zero, two,
# Nearest to the: its, their, his, a, an, any, communicative, our,
# Nearest to also: below, still, often, now, currently, queueing, disambiguation, never,
# Nearest to between: with, across, entomologist, administrations, against, among, encountering, dddddd,
# Nearest to only: always, ebay, actually, sanity, usually, steals, exception, cornelis,
# Nearest to time: beginning, times, end, point, period, rate, least, defeated,
# Nearest to may: can, must, will, should, could, might, would, cannot,
# Nearest to have: has, had, having, produce, include, contain, require, provide,
# Nearest to two: five, three, four, six, eight, zero, seven, nine,
# Nearest to with: between, languished, among, wt, paullus, eugenio, including, via,
# Nearest to to: could, will, can, must, towards, may, should, would,
# Nearest to be: refer, being, produce, respond, contain, lead, remain, provide,
# Nearest to about: over, acuity, around, ignite, five, kare, on, eca,
# Nearest to than: or, like, but, much, irate, beam, diem, dosages,
# Average loss at step 52000: 3.100390
# Average loss at step 54000: 3.091140
# Average loss at step 56000: 2.919648
# Average loss at step 58000: 3.034856
# Average loss at step 60000: 3.053468
# Nearest to th: nd, nineteenth, twentieth, st, rd, third, chopped, seventeenth,
# Nearest to by: timbers, through, thus, without, under, massed, kristina, before,
# Nearest to seven: five, six, eight, four, nine, three, zero, two,
# Nearest to the: its, their, a, his, an, this, any, sla,
# Nearest to also: below, now, sometimes, still, never, which, ffts, usually,
# Nearest to between: with, entomologist, across, among, through, during, over, sx,
# Nearest to only: still, killers, always, rebuilt, she, grotius, seldom, talleyrand,
# Nearest to time: beginning, times, point, period, end, least, year, conclusion,
# Nearest to may: can, should, must, might, could, will, would, cannot,
# Nearest to have: had, having, has, include, contain, produce, require, exist,
# Nearest to two: three, four, five, six, nine, eight, zero, seven,
# Nearest to with: between, among, tala, including, pessimistic, runnymede, while, ascribe,
# Nearest to to: could, would, will, must, might, dagbladet, should, cannot,
# Nearest to be: remain, have, lead, produce, being, refer, become, exist,
# Nearest to about: on, sidewalks, over, around, regarding, cyclopedia, approximately, thracians,
# Nearest to than: or, like, but, diethyl, diem, mitzvot, bentley, dk,
# Average loss at step 62000: 3.015072
# Average loss at step 64000: 2.929840
# Average loss at step 66000: 2.934031
# Average loss at step 68000: 2.951404
# Average loss at step 70000: 3.012620
# Nearest to th: nd, st, twentieth, nineteenth, rd, nine, seventeenth, third,
# Nearest to by: straddling, disfavor, flintlock, iqaluit, tapering, when, without, before,
# Nearest to seven: five, six, eight, three, four, zero, two, nine,
# Nearest to the: their, a, his, its, our, any, startled, an,
# Nearest to also: below, still, now, which, disambiguation, noirs, here, above,
# Nearest to between: with, within, entomologist, across, among, flavoured, through, pelagius,
# Nearest to only: seldom, even, salamander, phoenicians, semi, macht, supernaturally, uf,
# Nearest to time: period, age, course, times, beginning, least, moment, speed,
# Nearest to may: might, could, must, should, can, will, would, cannot,
# Nearest to have: had, has, having, contain, require, include, produce, find,
# Nearest to two: three, five, zero, six, eight, four, prof, seven,
# Nearest to with: between, tala, runnymede, among, vaduz, including, lfc, inerrancy,
# Nearest to to: will, must, might, dagbladet, cannot, could, may, can,
# Nearest to be: being, remain, refer, cause, respond, lead, become, been,
# Nearest to about: behind, regarding, on, lycaon, over, shutting, scratches, misnomer,
# Nearest to than: or, crony, beam, rastafari, overly, but, while, actinide,
# Average loss at step 72000: 2.945217
# Average loss at step 74000: 2.859946
# Average loss at step 76000: 2.999041
# Average loss at step 78000: 3.003500
# Average loss at step 80000: 2.843755
# Nearest to th: st, nd, nineteenth, twentieth, rd, seventeenth, eight, nine,
# Nearest to by: without, mah, through, massoud, timbers, encarta, bashir, iqaluit,
# Nearest to seven: six, five, eight, four, three, nine, zero, two,
# Nearest to the: our, a, their, another, its, his, any, your,
# Nearest to also: below, currently, now, often, still, sometimes, never, disambiguation,
# Nearest to between: with, among, entomologist, across, within, horch, serbs, through,
# Nearest to only: troubadors, always, jovi, usually, seldom, acclaimed, fully, metallica,
# Nearest to time: beginning, moment, month, period, battle, end, year, victory,
# Nearest to may: might, can, should, could, will, would, must, cannot,
# Nearest to have: had, has, having, require, contain, include, provide, find,
# Nearest to two: three, five, six, four, zero, several, nine, seven,
# Nearest to with: between, among, granitic, ionized, via, induces, christo, abercrombie,
# Nearest to to: might, will, should, would, cannot, may, must, towards,
# Nearest to be: remain, refer, being, produce, become, represent, provide, respond,
# Nearest to about: over, behind, approximately, regarding, ax, cet, gfdl, on,
# Nearest to than: unlike, diem, like, diethyl, stalking, or, unsettling, pacifism,
# Average loss at step 82000: 2.937750
# Average loss at step 84000: 2.896049
# Average loss at step 86000: 2.910468
# Average loss at step 88000: 2.943286
# Average loss at step 90000: 2.825042
# Nearest to th: twentieth, nd, st, nineteenth, seventeenth, rd, sixth, nine,
# Nearest to by: through, without, when, wap, mersey, ecuadorian, among, cg,
# Nearest to seven: eight, six, four, five, nine, three, zero, one,
# Nearest to the: its, a, their, an, any, another, our, his,
# Nearest to also: below, still, currently, which, disambiguation, never, stroll, sometimes,
# Nearest to between: with, among, across, entomologist, therefore, transducers, serbs, pelagius,
# Nearest to only: always, phipps, sip, predication, table, until, exception, entirely,
# Nearest to time: moment, least, times, beginning, period, end, start, point,
# Nearest to may: might, can, must, should, would, will, could, cannot,
# Nearest to have: has, had, having, contain, require, produce, represent, include,
# Nearest to two: three, four, six, five, nine, one, seven, pep,
# Nearest to with: between, among, tala, via, without, bnf, eugenio, egress,
# Nearest to to: will, must, cannot, may, towards, can, might, should,
# Nearest to be: being, refer, remain, occur, lead, represent, been, become,
# Nearest to about: over, approximately, ax, racist, cyclopedia, km, sokal, elision,
# Nearest to than: or, unlike, stalking, bentley, beam, hand, ivor, diem,
# Average loss at step 92000: 2.907355
# Average loss at step 94000: 2.888479
# Average loss at step 96000: 2.710726
# Average loss at step 98000: 2.455661
# Average loss at step 100000: 2.713367
# Nearest to th: nd, rd, twentieth, nineteenth, seventeenth, st, sixteenth, sixth,
# Nearest to by: through, straddling, tapering, timbers, among, mah, without, massoud,
# Nearest to seven: six, five, eight, four, three, zero, nine, two,
# Nearest to the: a, any, another, its, their, her, his, communicative,
# Nearest to also: below, often, currently, still, which, disambiguation, now, geysers,
# Nearest to between: with, across, through, in, among, within, hsv, entomologist,
# Nearest to only: first, troubadors, always, best, immediately, seldom, laguardia, jardines,
# Nearest to time: moment, period, point, distance, least, tusk, times, start,
# Nearest to may: might, would, should, could, must, can, will, cannot,
# Nearest to have: had, has, contain, having, require, include, produce, find,
# Nearest to two: four, three, five, seven, eight, six, zero, nine,
# Nearest to with: between, among, swims, tala, despite, bnf, by, through,
# Nearest to to: must, would, might, will, cannot, can, yelling, could,
# Nearest to be: remain, being, refer, become, lead, respond, ztt, occur,
# Nearest to about: regarding, over, cet, micah, related, manley, isi, on,
# Nearest to than: but, or, recently, bentley, energetic, like, stalking, diem,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# The results of CBOW model look similar to Word2Vec, but CBOW is more compact (more clear of clusters).
